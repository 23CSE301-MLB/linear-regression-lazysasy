# %%
import pandas as pd
df = pd.read_csv("advertising.csv")

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
x=df[['Newspaper']]
y=df[['Radio']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.5,random_state=32) # test_size - 50%

# %%
model = LinearRegression()
model.fit(x_train,y_train) # train model
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test) 
print(y_pred) # x - independent , y - dependent
# Out:
# [[19.28956791]
#  [21.77318995]
#  [20.14754643]
#  [38.54892793]
#  [24.97932022]
#  [35.95241398]
#  [24.55033096]
#  [20.93778981]
#  [27.14684492]
#  [22.4731198 ]
#  [20.93778981]
#  [21.95381701]
#  [22.99242259]
#  [21.68287642]
#  [31.41415916]
#  [18.65737321]
#  [21.00552496]
#  [28.36607756]
#  [17.0091513 ]
#  [33.64941899]
#  [18.61221644]
#  [23.82782273]
#  [21.0732601 ]
#  [22.69890362]
#  [25.54377978]
#  [23.53430376]
#  [25.11479052]
#  [16.60274042]
#  [20.98294657]
#  [22.83437391]
#  [16.98657292]
#  [19.89918423]
#  [20.59911408]
#  [25.47604463]
#  [17.09946483]
#  [32.83659723]
#  [27.66614771]
#  [18.72510835]
#  [17.73165954]
#  [17.43814057]
#  [27.1694233 ]
#  [17.91228659]
#  [24.27939038]
#  [17.21235674]
#  [20.1927032 ]
#  [18.18322718]
#  [15.83507543]
#  [17.21235674]
#  [31.97861871]
#  [26.1533961 ]
#  [17.86712983]
#  [26.96621786]
#  [19.37988144]
#  [17.79939468]
#  [28.77248844]
#  [30.6013374 ]
#  [19.10894085]
#  [19.51535173]
# ...

# %%
print("Coefficient (slope):", model.coef_)
print("Intercept:", model.intercept_)
print("R² score:", r2_score(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# Coefficient (slope): [[0.22578382]]
# Intercept: [15.76734028]
# R² score: 0.15286157811023104
# MSE: 183.8643555980269

# %%
plt.scatter(x_test, y_test, color='blue', label='Actual')
plt.plot(x_test, y_pred, color='red', linewidth=2, label='Predicted')
plt.xlabel('Newspaper')
plt.ylabel('Radio')
plt.legend()
plt.title("Simple Linear Regression")
plt.show()

# %%
x1_train,x1_test,y1_train,y1_test = train_test_split(x,y,test_size=70,random_state=32) # test_size - 70%

# %%
model = LinearRegression()
model.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
y1_pred = model.predict(x1_test)
print(y1_pred)
# Out:
# [[21.19432725]
#  [23.60444178]
#  [22.02691227]
#  [39.8836699 ]
#  [26.71568053]
#  [37.36400471]
#  [26.29938802]
#  [22.79376689]
#  [28.81905321]
#  [24.28365587]
#  [22.79376689]
#  [23.77972284]
#  [24.78758891]
#  [23.51680125]
#  [32.96006817]
#  [20.58084356]
#  [22.85949729]
#  [30.00220034]
#  [18.98140392]
#  [35.12917124]
#  [20.53702329]
#  [25.5982638 ]
#  [22.92522769]
#  [24.50275719]
#  [27.26343383]
#  [25.31343208]
#  [26.84714132]
#  [18.58702154]
#  [22.83758716]
#  [24.63421799]
#  [18.95949378]
#  [21.78590082]
#  [22.46511491]
#  [27.19770344]
#  [19.06904444]
#  [34.34040649]
#  [29.32298625]
#  [20.64657395]
#  [19.68252814]
#  [19.39769643]
#  [28.84096334]
#  [19.8578092 ]
#  [26.03646644]
#  [19.1785951 ]
#  [22.07073254]
#  [20.12073078]
#  [17.84207705]
#  [19.1785951 ]
#  [33.50782147]
#  [27.8550074 ]
#  [19.81398893]
#  [28.64377215]
#  [21.28196778]
#  [19.74825854]
#  [30.39658272]
#  [32.17130341]
#  [21.0190462 ]
#  [21.41342857]
# ...

# %%
print("Coefficient (slope):", model.coef_)
print("Intercept:", model.intercept_)
print("R² score:", r2_score(y1_test, y1_pred))
print("MSE:", mean_squared_error(y1_test, y1_pred))
# Out:
# Coefficient (slope): [[0.21910132]]
# Intercept: [17.77634665]
# R² score: 0.138247129675922
# MSE: 173.79558238192695

# %%
plt.scatter(x1_test, y1_test, color='blue', label='Actual')
plt.plot(x1_test, y1_pred, color='red', linewidth=2, label='Predicted')
plt.xlabel('Newspaper')
plt.ylabel('Radio')
plt.legend()
plt.title("Simple Linear Regression")
plt.show()

# %%
x3_train,x3_test,y3_train,y3_test = train_test_split(x,y,test_size=60,random_state=32) # test_size - 60%

# %%
model = LinearRegression()
model.fit(x3_train,y3_train)
# Out:
# LinearRegression()

# %%
y3_pred = model.predict(x3_test)
print(y3_pred)
# Out:
# [[21.58922043]
#  [23.92876965]
#  [22.39742834]
#  [39.73136123]
#  [26.94891501]
#  [37.28546886]
#  [26.54481106]
#  [23.14183037]
#  [28.99070343]
#  [24.58809716]
#  [23.14183037]
#  [24.09891869]
#  [25.07727564]
#  [23.84369514]
#  [33.01047437]
#  [20.99369881]
#  [23.20563626]
#  [30.13920941]
#  [19.44108887]
#  [35.11606867]
#  [20.95116155]
#  [25.86421492]
#  [23.26944214]
#  [24.80078345]
#  [27.48063075]
#  [25.58772274]
#  [27.07652679]
#  [19.05825354]
#  [23.18436763]
#  [24.92839523]
#  [19.41982024]
#  [22.16347342]
#  [22.82280093]
#  [27.41682486]
#  [19.52616339]
#  [34.35039801]
#  [29.4798819 ]
#  [21.0575047 ]
#  [20.12168501]
#  [19.84519283]
#  [29.01197206]
#  [20.29183404]
#  [26.28958751]
#  [19.63250653]
#  [22.4399656 ]
#  [20.54705759]
#  [18.33512014]
#  [19.63250653]
#  [33.5421901 ]
#  [28.05488374]
#  [20.24929678]
#  [28.82055439]
#  [21.67429495]
#  [20.18549089]
#  [30.52204474]
#  [32.24480371]
#  [21.41907139]
#  [21.80190672]
# ...

# %%
print("Coefficient (slope):", model.coef_)
print("Intercept:", model.intercept_)
print("R² score:", r2_score(y3_test, y3_pred))
print("MSE:", mean_squared_error(y3_test, y3_pred))
# Out:
# Coefficient (slope): [[0.21268629]]
# Intercept: [18.27131426]
# R² score: 0.10177383757644409
# MSE: 170.0571771956651

# %%
plt.scatter(x3_test, y3_test, color='blue', label='Actual')
plt.plot(x3_test, y3_pred, color='red', linewidth=2, label='Predicted')
plt.xlabel('Newspaper')
plt.ylabel('Radio')
plt.legend()
plt.title("Simple Linear Regression")
plt.show()

# %%
x1=df[['Newspaper','TV']]
y1=df['Sales']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x1,y1,test_size=0.3,random_state=32)

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_p=model.predict(X_test)
print(y_p)
# Out:
# [19.32321672 14.86607174 18.44758129 25.06081849 11.33773612  9.34802771
#  12.71708333 20.84460722  8.66329313 10.31536925 20.36276565 19.25761908
#  19.8769432  19.77607655  8.95750747 16.18714604 12.07784434 23.3165343
#  20.85769657 15.16721042 14.7708007  12.29226917 20.22538191 16.77679418
#   8.86839886 13.09115994  7.84407666 22.51598977 13.49365144 14.40189328
#  13.20159006 10.80444974 22.55328433 22.16004173 17.66459848 18.86040861
#  11.82800492 19.18396343  6.81618695 12.05134316 12.82466369 17.19475421
#  16.85212174 16.53381402 18.35194103 18.42643392 21.31728568 22.47652665
#  23.98400359 18.83684044  8.20740404  8.33693784 11.15108912 14.55388228
#  19.69764439 18.63218716 11.13232094 14.48074929 13.63592095 17.28733405]

# %%
print("Coefficient (slope):", model.coef_)
print("Intercept:", model.intercept_)
print("R² score:", r2_score(Y_test, y_p))
print("MSE:", mean_squared_error(Y_test, y_p))
# Out:
# Coefficient (slope): [0.0202555  0.05538409]
# Intercept: 6.601195277811371
# R² score: 0.8147343445023275
# MSE: 4.972429326700646
